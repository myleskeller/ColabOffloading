# %% [markdown]
# <a href="https://colab.research.google.com/github/myleskeller/ColabOffloading/blob/main/blenderCLI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Blender Rendering Script for Colab
# This is a script for performing command line Blender renders in Google Collab.
#
#
#
# Prior to use:
# - Make sure that your `.blend` file has **GPU Compute** set as the render device.
# - Make sure that the Colab runtime hardware accelerator is set to **GPU**.
#
# Notes:
# - If rendering on the GPU doesn't work for whatever reason, you can use CPU rendering. **In my testing, GPU was 98.73% faster than CPU.**

# %% [markdown]
# # Configuration

# %%
#@title Blender Parameters

renderer = "CYCLES" #@param ["CYCLES", "BLENDER_EEVEE", "BLENDER_WORKBENCH"]
samples = 1000 #@param {type:"integer"}
frame = 1 #@param {type:"integer"}
blender_version = "2.92.0" #@param {type:"string"}
render_hardware = "GPU" #@param ["GPU", "CPU"]

# %% [markdown]
# # File Source
# Choose one.

# %%
#@title Direct Upload { vertical-output: true }

from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  drive_file_path = './' + fn

#@markdown - Click *Choose Files* below 
#@markdown - Find the desired `.blend` file

# input file path
print("File path: " + drive_file_path)
# output file path
output_file = "//" + fn.split('.')[0] + '_'
# print(output_file)

# %%
#@title Google Drive { vertical-output: true }

# actual gogle drive stuff
from google.colab import drive
drive.mount('/content/drive')

#@markdown - In the *Files* pane, find the desired `.blend` file  under the folder **drive**
#@markdown - click *Copy path* in the overflow menu of the file
#@markdown - paste the result in the input field below

# input file path
drive_file_path = '/content/drive/MyDrive/blender/hand.blend' #@param {type: "string"}
# output file path
output_file = "//" + drive_file_path.split('/')[-1].split('.')[0] + '_'
# print(output_file)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Render

# %%
#@title Attempt to Prevent Disconnects { vertical-output: true }
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %%
#@title Install Blender
blender_version_trimmed = blender_version.rstrip('0').rstrip('.')
blender_url = "https://download.blender.org/release/Blender" + blender_version_trimmed + "/blender-" + blender_version + "-linux64.tar.xz"
blender_tar = "blender-" + blender_version + "-linux64.tar.xz"
blender_path = "./blender-" + blender_version + "-linux64/blender"

# !apt install blender
# !wget https://download.blender.org/release/Blender2.92/blender-2.92.0-linux64.tar.xz
# !tar xf blender-2.92.0-linux64.tar.xz
# !./blender-2.92.0-linux64/blender -v

# downloading python script to enable GPU rendering
# !wget https://raw.githubusercontent.com/myleskeller/ColabOffloading/main/blender_gpu.py
# downloading python script to assign number of samples
# !wget https://raw.githubusercontent.com/myleskeller/ColabOffloading/main/samples.py

# installing supporting libraries
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev

# downloading and extracting blender
# !wget $blender_url
# !tar xf $blender_tar

# attempting to fix that stupid "src/tcmalloc.cc:283] Attempt to free invalid pointer 0x7f9aa682b000" error..
# !sudo apt remove libtcmalloc-minimal4
# !sudo apt-get install libtcmalloc-minimal4
# consequently, it always shows "ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored." in the CLI, but it doesn't seem to impact functionality.

# if this outputs the blender version, it'll probably work.
# !$blender_path -v
# Out:
# --2021-04-22 00:49:52--  https://raw.githubusercontent.com/myleskeller/ColabOffloading/main/blender_gpu.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 790 [text/plain]
# Saving to: ‘blender_gpu.py’
#
# blender_gpu.py      100%[===================>]     790  --.-KB/s    in 0s
#
# 2021-04-22 00:49:52 (48.1 MB/s) - ‘blender_gpu.py’ saved [790/790]
#
# --2021-04-22 00:49:52--  https://raw.githubusercontent.com/myleskeller/ColabOffloading/main/samples.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 829 [text/plain]
# Saving to: ‘samples.py’
#
# samples.py          100%[===================>]     829  --.-KB/s    in 0s
#
# 2021-04-22 00:49:53 (30.7 MB/s) - ‘samples.py’ saved [829/829]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# --2021-04-22 00:49:57--  https://download.blender.org/release/Blender2.92/blender-2.92.0-linux64.tar.xz
# Resolving download.blender.org (download.blender.org)... 82.94.213.221
# Connecting to download.blender.org (download.blender.org)|82.94.213.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153630696 (147M) [application/octet-stream]
# Saving to: ‘blender-2.92.0-linux64.tar.xz’
#
# blender-2.92.0-linu 100%[===================>] 146.51M  7.52MB/s    in 32s
#
# 2021-04-22 00:50:29 (4.53 MB/s) - ‘blender-2.92.0-linux64.tar.xz’ saved [153630696/153630696]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages will be REMOVED:
#   google-perftools libgoogle-perftools4 libtcmalloc-minimal4
# 0 upgraded, 0 newly installed, 3 to remove and 31 not upgraded.
# After this operation, 2,187 kB disk space will be freed.
# (Reading database ... 160983 files and directories currently installed.)
# Removing google-perftools (2.5-2.2ubuntu3) ...
# Removing libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Removing libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libtcmalloc-minimal4
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 91.6 kB of archives.
# After this operation, 380 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtcmalloc-minimal4 amd64 2.5-2.2ubuntu3 [91.6 kB]
# Fetched 91.6 kB in 0s (199 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libtcmalloc-minimal4.
# (Reading database ... 160909 files and directories currently installed.)
# Preparing to unpack .../libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Blender 2.92.0
# 	build date: 2021-02-25
# 	build time: 09:31:37
# 	build commit date: 2021-02-24
# 	build commit time: 16:25
# 	build hash: 02948a2cab44
# 	build platform: Linux
# 	build type: Release
# 	build c flags:  -Wall -Wcast-align -Werror=implicit-function-declaration -Werror=return-type -Werror=vla -Wstrict-prototypes -Wmissing-prototypes -Wno-char-subscripts -Wno-unknown-pragmas -Wpointer-arith -Wunused-parameter -Wwrite-strings -Wlogical-op -Wundef -Winit-self -Wmissing-include-dirs -Wno-div-by-zero -Wtype-limits -Wformat-signedness -Wrestrict -Wnonnull -Wabsolute-value -Wuninitialized -Wredundant-decls -Wshadow -Wno-error=unused-but-set-variable -Wimplicit-fallthrough=5  -fuse-ld=gold -std=gnu11 -msse -pipe -fPIC -funsigned-char -fno-strict-aliasing -ffp-contract=off -msse2 -D_GLIBCXX_USE_CXX11_ABI=0
# 	build c++ flags:  -Wredundant-decls -Wall -Wno-invalid-offsetof -Wno-sign-compare -Wlogical-op -Winit-self -Wmissing-include-dirs -Wno-div-by-zero -Wtype-limits -Werror=return-type -Wno-char-subscripts -Wno-unknown-pragmas -Wpointer-arith -Wunused-parameter -Wwrite-strings -Wundef -Wformat-signedness -Wrestrict -Wuninitialized -Wundef -Wmissing-declarations -Wimplicit-fallthrough=5  -fuse-ld=gold -std=c++17 -msse -pipe -fPIC -funsigned-char -fno-strict-aliasing -ffp-contract=off -msse2 -D_GLIBCXX_USE_CXX11_ABI=0
# 	build link flags:  -Wl,--version-script='/home/sources/buildbot-worker-linux_centos7/linux_292/blender.git/source/creator/blender.map'
# 	build system: CMake

# %%
#@title Render on GPU
if (render_hardware == "GPU"):
  print("rendering file located at: "+drive_file_path+"\n")

  # !$blender_path -b $drive_file_path -F PNG -noaudio -o $output_file -E $renderer -x 1 -P blender_gpu.py -P samples.py -f $frame -- $samples
  # -b = Render in the background (without UI).
  # -o = Path of where to save the rendered image, using five padded zeros for the frame number.
  # -E = Use the «$renderer» rendering engine.
  # -x = Set option to add the file extension to the end of the file. (boolean)
  # -P = load the «filename» python script.
  # -f = $frame = Render only the «$frame»th frame.
# Out:
# rendering file located at: /content/drive/MyDrive/blender/hand.blend
#
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Blender 2.92.0 (hash 02948a2cab44 built 2021-02-25 09:31:37)
# ERROR: ld.so: object '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4' from LD_PRELOAD cannot be preloaded (cannot open shared object file): ignored.
# Read blend: /content/drive/MyDrive/blender/hand.blend
# Fra:1 Mem:116.44M (Peak 152.09M) | Time:00:01.35 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | human_male_base03
# Fra:1 Mem:142.26M (Peak 152.09M) | Time:00:01.44 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Initializing
# Fra:1 Mem:87.60M (Peak 152.09M) | Time:00:01.45 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Waiting for render to start
# Fra:1 Mem:87.62M (Peak 152.09M) | Time:00:01.45 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:87.62M (Peak 152.09M) | Time:00:01.48 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene
# Fra:1 Mem:87.62M (Peak 152.09M) | Time:00:01.48 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Shaders
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Background
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Camera
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Meshes Flags
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Objects
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Particle Systems
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:88.12M (Peak 152.09M) | Time:00:01.59 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Meshes
# Fra:1 Mem:96.52M (Peak 152.09M) | Time:00:01.61 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:96.52M (Peak 152.09M) | Time:00:01.61 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:96.52M (Peak 152.09M) | Time:00:01.61 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Building
# Fra:1 Mem:96.52M (Peak 152.09M) | Time:00:01.61 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:128.02M (Peak 152.09M) | Time:00:01.89 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Building BVH 50%, duplicates 0%
# Fra:1 Mem:128.02M (Peak 152.09M) | Time:00:02.08 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:157.42M (Peak 157.42M) | Time:00:02.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:184.90M (Peak 184.90M) | Time:00:02.17 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:187.00M (Peak 187.00M) | Time:00:02.19 | Mem:44.19M, Peak:44.19M | Scene, RenderLayer | Updating Mesh | Computing normals
# Fra:1 Mem:205.97M (Peak 205.97M) | Time:00:02.20 | Mem:44.19M, Peak:44.19M | Scene, RenderLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.16M, Peak:63.16M | Scene, RenderLayer | Updating Objects Flags
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.16M, Peak:63.16M | Scene, RenderLayer | Updating Images
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.16M, Peak:63.16M | Scene, RenderLayer | Updating Camera Volume
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.16M, Peak:63.16M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.41M, Peak:63.41M | Scene, RenderLayer | Updating Lights
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.41M, Peak:63.41M | Scene, RenderLayer | Updating Lights | Computing distribution
# Fra:1 Mem:203.87M (Peak 205.97M) | Time:00:02.21 | Mem:63.41M, Peak:63.41M | Scene, RenderLayer | Updating Integrator
# Fra:1 Mem:205.14M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Updating Film
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.44M, Peak:64.69M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Updating Baking
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Updating Device | Writing constant memory
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Updating Device | Writing constant memory | Compiling render kernels
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Updating Device | Writing constant memory
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.69M | Scene, RenderLayer | Rendered 0/510 Tiles, Sample 0/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 1/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 2/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 3/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 4/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 5/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 6/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 7/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 8/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 9/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 10/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 11/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 12/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 13/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 14/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 15/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 16/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 17/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 18/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 19/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 20/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 21/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 22/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 23/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 24/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 25/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 26/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 27/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 28/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.22 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 29/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 30/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 31/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 32/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 33/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 34/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 35/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 36/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 37/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 38/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 39/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 40/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 41/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 42/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 43/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 44/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 45/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 46/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 47/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 48/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 49/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.23 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 50/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 51/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 52/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 53/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 54/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 55/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 56/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 57/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 58/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 59/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 60/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 61/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 62/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 63/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 64/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 65/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 66/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 67/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 68/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 69/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.24 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 70/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 71/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 72/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 73/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 74/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 75/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 76/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 77/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 78/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 79/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 80/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 81/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 82/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 83/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 84/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 85/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 86/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 87/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 88/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.25 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 89/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 90/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 91/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 92/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 93/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 94/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 95/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 96/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.26 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 97/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 98/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 99/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 100/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 101/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 102/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 103/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 104/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 105/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.27 | Remaining:00:00.10 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 106/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.10 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 107/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.11 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 108/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.11 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 109/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.11 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 110/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 111/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 112/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 113/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 114/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 115/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 116/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 117/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.28 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 118/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 119/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 120/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 121/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 122/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 123/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 124/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 125/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 126/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 127/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 128/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 129/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 130/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 131/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 132/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 133/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.29 | Remaining:00:00.12 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 134/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.30 | Remaining:00:00.13 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 135/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.30 | Remaining:00:00.13 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 136/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.30 | Remaining:00:00.14 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 137/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.15 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 138/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.15 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 139/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.15 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 140/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 141/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 142/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 143/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 144/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 145/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 146/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.31 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 147/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 148/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 149/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 150/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 151/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 152/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 153/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 154/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 155/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 156/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 157/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 158/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 159/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 160/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 161/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.32 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 162/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.33 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 163/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.33 | Remaining:00:00.16 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 164/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.33 | Remaining:00:00.17 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 165/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.33 | Remaining:00:00.17 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 166/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.34 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 167/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.34 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 168/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.34 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 169/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.34 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 170/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 171/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 172/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 173/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 174/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 175/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 176/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 177/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 178/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 179/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 180/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 181/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 182/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 183/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 184/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 185/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.35 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 186/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 187/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 188/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 189/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 190/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 191/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 192/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.36 | Remaining:00:00.18 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 193/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.37 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 194/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.37 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 195/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.37 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 196/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.37 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 197/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.38 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 198/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.38 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 199/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.38 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 200/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.38 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 201/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 202/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 203/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 204/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 205/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 206/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 207/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 208/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 209/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 210/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 211/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 212/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 213/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 214/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.39 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 215/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 216/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 217/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 218/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 219/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 220/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 221/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.40 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 222/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 223/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 224/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 225/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 226/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 227/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.41 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 228/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.42 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 229/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.42 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 230/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.42 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 231/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 232/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 233/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.21 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 234/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 235/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 236/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 237/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 238/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 239/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 240/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 241/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 242/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 243/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 244/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 245/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 246/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 247/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.43 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 248/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.44 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 249/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.44 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 250/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.44 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 251/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.44 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 252/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.45 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 253/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.45 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 254/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.45 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 255/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.45 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 256/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.45 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 257/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.46 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 258/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.46 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 259/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.46 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 260/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 261/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 262/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 263/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 264/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 265/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 266/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 267/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.20 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 268/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 269/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.47 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 270/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 271/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 272/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 273/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 274/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 275/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 276/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 277/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 278/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.48 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 279/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.49 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 280/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.49 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 281/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.49 | Remaining:00:00.19 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 282/510 Tiles, Sample 10/10
# ...
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 410/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 411/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 412/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 413/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 414/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.09 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 415/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 416/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 417/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 418/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 419/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 420/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.66 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 421/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 422/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 423/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 424/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.08 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 425/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 426/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 427/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 428/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 429/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.67 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 430/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 431/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 432/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 433/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 434/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.07 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 435/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 436/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 437/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 438/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 439/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 440/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 441/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 442/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 443/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.06 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 444/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 445/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 446/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 447/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 448/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 449/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.68 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 450/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 451/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 452/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 453/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.05 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 454/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 455/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 456/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 457/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 458/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 459/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 460/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 461/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 462/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 463/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.04 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 464/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 465/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 466/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 467/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 468/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 469/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.69 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 470/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 471/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 472/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 473/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.03 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 474/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 475/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 476/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 477/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 478/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 479/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 480/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 481/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 482/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 483/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 484/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.02 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 485/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 486/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 487/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 488/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 489/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 490/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 491/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 492/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 493/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.70 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 494/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 495/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 496/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.01 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 497/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 498/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 499/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 500/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 501/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 502/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 503/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 504/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 505/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 506/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 507/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 508/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Remaining:00:00.00 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 509/510 Tiles, Sample 10/10
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Rendered 510/510 Tiles
# Fra:1 Mem:205.15M (Peak 205.97M) | Time:00:02.71 | Mem:64.69M, Peak:64.81M | Scene, RenderLayer | Finished
# Saved: '/content/drive/MyDrive/blender/hand_0001.png'
#  Time: 00:04.63 (Saving: 00:01.86)
#
#
# Blender quit

# %%
#@title Render on CPU (fallback)

if (render_hardware == "CPU"):
  print("rendering file located at: "+drive_file_path+"\n")
  # !$blender_path -b $drive_file_path -noaudio -o $output_file -F PNG -E $renderer -x 1 -P samples.py -f $frame -- $samples
  # -b = Render in the background (without UI).
  # -o = Path of where to save the rendered image, using five padded zeros for the frame number.
  # -F = Set the render format. Valid options are: TGA RAWTGA JPEG IRIS IRIZ AVIRAW AVIJPEG PNG BMP
  # -E = Use the «$renderer» rendering engine.
  # -x = Set option to add the file extension to the end of the file. (boolean)
  # -f = $frame = Render only the «$frame»th frame.

# %% [markdown]
# # Results

# %%
#@title Display Result
from IPython.display import Image
import os.path
from os import path

final_output = output_file.replace("//","./") + str(frame).zfill(4) + ".png";
# print(final_output)

if (path.exists(final_output) == False):
  file_actual = drive_file_path.split('.')[0].split('/')[-1]
  path_mostly = drive_file_path.split('.')[0]
  out = path_mostly.replace(file_actual, final_output.replace("./",""))
else:
  out = final_output

Image(filename=out)

# %%
#@title Download Result { vertical-output: true }
from google.colab import files
files.download(out)
